# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('car data (2).csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
# df.columns

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
# checking for null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
final_df=df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_df['current_year']= 2022

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  current_year
# 0       Manual      0          2022
# 1       Manual      0          2022
# 2       Manual      0          2022
# 3       Manual      0          2022
# 4       Manual      0          2022

# %%
final_df['Number_of_years']=final_df['current_year']-final_df['Year']

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  current_year  Number_of_years
# 0       Manual      0          2022                8
# 1       Manual      0          2022                9
# 2       Manual      0          2022                5
# 3       Manual      0          2022               11
# 4       Manual      0          2022                8

# %%
final_df.drop(['Year','current_year'],axis=1 , inplace=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Number_of_years
# 0       Manual      0                8
# 1       Manual      0                9
# 2       Manual      0                5
# 3       Manual      0               11
# 4       Manual      0                8

# %%
#converting categorical features
final_df = pd.get_dummies(final_df,drop_first=True)

# %%
final_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Number_of_years  \
# 0           3.35           5.59       27000      0                8
# 1           4.75           9.54       43000      0                9
# 2           7.25           9.85        6900      0                5
# 3           2.85           4.15        5200      0               11
# 4           4.60           6.87       42450      0                8
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
final_df.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# Number_of_years             -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         Number_of_years  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price                 -0.236141          0.552339         -0.540571
# Present_Price                  0.047584          0.473306         -0.465244
# Kms_Driven                     0.524342          0.172515         -0.172874
# Owner                          0.182104         -0.053469          0.055687
# Number_of_years                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel              -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol               0.059959         -0.979648          1.000000
# Seller_Type_Individual         0.039896         -0.350467          0.358321
# Transmission_Manual           -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# Number_of_years                       0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
sns.pairplot(final_df)

# %%
corrmat=final_df.corr()
top_features = corrmat.index
plt.figure(figsize=(12,9))
# plot heatmap
h= sns.heatmap(final_df[top_features].corr(),annot = True , cmap= 'RdYlGn')

# %%
# independent and dependent feature
X = final_df.iloc[:,1:]
y = final_df.iloc[:,0]

# %%
### feature importances
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [3.80105121e-01 4.00606399e-02 3.45943373e-04 7.31786308e-02
#  2.32144515e-01 1.26691407e-02 1.23252835e-01 1.38243173e-01]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh') 
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2)

# %%
X_train.shape
# Out:
# (240, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random = RandomForestRegressor()

# %%
## hyperparameter
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
 #Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs=1)

# %% [raw]
# rf_random.fit(X_train, y_train)

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, n_estimators=700; total time=   2.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, n_estimators=700; total time=   1.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, n_estimators=700; total time=   2.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, n_estimators=700; total time=   2.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, n_estimators=700; total time=   2.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=1100; total time=   3.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=1100; total time=   3.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=1100; total time=   3.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=1100; total time=   2.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, n_estimators=1100; total time=   3.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, n_estimators=1100; total time=   2.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, n_estimators=1100; total time=   3.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, n_estimators=1100; total time=   2.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, n_estimators=1100; total time=   3.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, n_estimators=1100; total time=   3.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   2.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   2.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   2.3s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   1.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   2.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   1.9s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   1.9s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   1.5s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   2.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=700; total time=   2.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=500; total time=   1.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=500; total time=   1.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, n_estimators=500; total time=   1.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, n_estimators=800; total time=   1.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, n_estimators=800; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, n_estimators=800; total time=   1.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, n_estimators=800; total time=   1.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, n_estimators=800; total time=   1.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, n_estimators=600; total time=   1.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, n_estimators=600; total time=   1.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, n_estimators=600; total time=   1.5s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, n_estimators=600; total time=   1.2s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=5, n_estimators=600; total time=   1.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=1100; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=1100; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=1100; total time=   2.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=1100; total time=   2.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=1100; total time=   2.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, n_estimators=900; total time=   2.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, n_estimators=900; total time=   2.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, n_estimators=900; total time=   2.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, n_estimators=900; total time=   2.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=10, n_estimators=900; total time=   2.1s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 700,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 25}

# %%
rf_random.best_score_
# Out:
# -2.9837223997877227

# %%
predictions=rf_random.predict(X_test)

# %%
predictions
# Out:
# array([ 5.6725737 ,  0.44202367,  5.24062134,  5.66653481, 22.74263206,
#        20.00360219,  6.93485805,  0.52273061,  0.49894962, 16.15915712,
#         9.16608832,  0.52611111,  5.09456763,  5.23660737,  2.44041553,
#         0.2148076 ,  5.63763673,  0.17874984,  4.51850737,  0.93825119,
#         0.62900226,  5.713146  ,  0.30756039,  3.81208914,  5.01700349,
#         9.7691755 ,  7.32139063,  2.68138727,  2.83206267,  1.05848562,
#         0.490402  ,  3.7763888 ,  1.20495036,  5.06678656, 20.06873219,
#         4.59283319,  5.53306165,  0.44254443,  0.29358276,  1.14149207,
#         0.15814494,  0.45926841,  0.27030352,  0.33041554,  5.06119913,
#         6.6383027 ,  4.03025828, 15.26737804,  9.61186711,  0.49320906,
#         9.12865675,  0.14476016,  5.59149388,  0.57025771,  0.45968566,
#         5.20636607,  0.28756747,  2.80353381,  6.25614849, 10.77284086,
#        10.56598851])

# %%
sns.distplot(y_test-predictions)
# Out:
# C:\Users\Lenovo\anaconda3\envs\cardekho\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
print ("R2_Score : ", r2_score( y_test, predictions))
# Out:
# MAE: 0.9112111048520827
# MSE: 5.036730947301372
# RMSE: 2.2442662380612
# R2_Score :  0.7544176233209341

# %%
import pickle
# open a file where you want to store a data
file = open('random_forest_regression_model.pkl', 'wb')
# dump imformation to that file
pickle.dump(rf_random, file)
